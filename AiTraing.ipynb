# %% [markdown]
# <a href="https://colab.research.google.com/github/Odwa2003/FirstWebapp/blob/main/AiTraing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e47b380d-37d2-46a9-a763-9a6237b13789" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e47b380d-37d2-46a9-a763-9a6237b13789">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Read the Excel

# %%
# Replace with your uploaded filename
file_name = "aviatorData.xlsx"

# Read the first sheet
df = pd.read_excel(file_name)
df
# Out:
#       Muliplier  No. Players who cashed out  Bets that made money  \
# 0          1.32                       -2482                   -11
# 1          5.18                         935                  2588
# 2          2.43                         527                  1654
# 3          9.13                        1831                  3943
# 4          1.06                         -33                    15
# ...         ...                         ...                   ...
# 4108       1.13                           3                    18
# 4109       1.51                          29                    89
# 4110       3.60                         331                   936
# 4111      20.36                         998                  1920
# 4112       4.63                         485                  1246
#
#       Total Earnings from players        Date and time
# 0                            0.00  2025-08-17 20:17:14
# 1                        32383.44  2025-08-17 20:17:38
# ...

# %% [markdown]
# #**Data prep**

# %% [markdown]
# ## **Data Separation as x and y**

# %%
y = df['Muliplier']
y
# Out:
# 0        1.32
# 1        5.18
# 2        2.43
# 3        9.13
# 4        1.06
#         ...
# 4108     1.13
# 4109     1.51
# 4110     3.60
# 4111    20.36
# 4112     4.63
# Name: Muliplier, Length: 4113, dtype: float64

# %%
x = df.drop('Muliplier', axis=1)
x
# Out:
#       No. Players who cashed out  Bets that made money  \
# 0                          -2482                   -11
# 1                            935                  2588
# 2                            527                  1654
# 3                           1831                  3943
# 4                            -33                    15
# ...                          ...                   ...
# 4108                           3                    18
# 4109                          29                    89
# 4110                         331                   936
# 4111                         998                  1920
# 4112                         485                  1246
#
#       Total Earnings from players        Date and time
# 0                            0.00  2025-08-17 20:17:14
# 1                        32383.44  2025-08-17 20:17:38
# 2                        10865.78  2025-08-17 20:17:59
# 3                        40801.41  2025-08-17 20:18:35
# ...

# %% [markdown]
# ##Data Splitting

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

# %%
x_train
# Out:
#       No. Players who cashed out  Bets that made money  \
# 652                            0                   -11
# 3042                          75                   174
# 1280                           0                     0
# 1640                           6                    24
# 3674                          40                   125
# ...                          ...                   ...
# 802                           89                   268
# 1890                         448                  1012
# 350                            8                    46
# 79                           392                  1448
# 3927                         438                  1068
#
#       Total Earnings from players        Date and time
# 652                          0.00  2025-08-18 00:21:20
# 3042                      4390.82  2025-08-19 03:51:53
# 1280                         0.00  2025-08-18 04:10:22
# 1640                         0.00  2025-08-18 06:18:36
# ...

# %%
x_test
# Out:
#       No. Players who cashed out  Bets that made money  \
# 219                          803                  1781
# 2905                          76                   193
# 3954                          58                   223
# 3235                         108                   264
# 1645                         371                   787
# ...                          ...                   ...
# 1339                           9                    34
# 1410                           8                    14
# 3776                         318                   776
# 344                          131                   351
# 1913                          61                   180
#
#       Total Earnings from players        Date and time
# 219                      26807.87  2025-08-17 21:41:58
# 2905                      5478.96  2025-08-19 03:02:24
# 3954                      2383.61  2025-08-19 09:18:38
# 3235                      3559.80  2025-08-19 04:57:56
# ...

# %% [markdown]
# #**Model building**

# %% [markdown]
# ##**Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2966537346.py in <cell line: 0>()
#       1 from sklearn.linear_model import LinearRegression
#       2 lr = LinearRegression()
# ----> 3 lr.fit(x_train, y_train)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     599         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     600
# --> 601         X, y = validate_data(
#     602             self,
#     603             X,
#
# ...
